# %%
from DLtools.Data import instant_data
import pandas as pd
ori=pd.read_csv('/home/song/Public/Song/Work/Thesis/data/instant_data/all/water_ori.csv')
new=pd.read_csv('/home/song/Public/Song/Work/Thesis/data/instant_data/all/water_edit_notwork.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-d876ebe25131> in <module>
# ----> 1 from DLtools.Data import instant_data
#       2 import pandas as pd
#       3 ori=pd.read_csv('/home/song/Public/Song/Work/Thesis/data/instant_data/all/water_ori.csv')
#       4 new=pd.read_csv('/home/song/Public/Song/Work/Thesis/data/instant_data/all/water_edit_notwork.csv')
#
# ModuleNotFoundError: No module named 'DLtools'

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20,5))
ori['CPY012_wl'].plot(legend=True,label='ori')
new['CPY012_wl'].plot(legend=True,label='new')
# Out:
# <AxesSubplot:>
