# %%
import pandas as pd
import re,glob, os
import numpy as np

# %%
def rename(path_name):
    path_name = re.search('[^\/]+$',path_name).group(0)
    return path_name[:-4]

def df_process(file):
    try:
        df = pd.read_csv(file,parse_dates=[['date', 'time']])
        
    except:
        df = pd.read_csv(file,parse_dates=['date'])
    df.replace({-999:np.nan},inplace=True)
    df['station'] = rename(file)
    return df

def open_concat_csv(folder_path):
    all_filenames = [i for i in glob.glob(os.path.join(folder_path, '*.csv'))]
    df = pd.concat([df_process(f) for f in all_filenames])
    return df

# %% [markdown]
# # Rain

# %%
path_rain = "hii-telemetering-batch-data-master/rain2007-2020/"
rain_df = open_concat_csv(path_rain)

print(rain_df.shape)
rain_df.head()
# Out:
# (4601312, 3)
#         date  rain station
# 0 2007-01-01   NaN  SWR028
# 1 2007-01-02   NaN  SWR028
# 2 2007-01-03   NaN  SWR028
# 3 2007-01-04   NaN  SWR028
# 4 2007-01-05   NaN  SWR028

# %%
df = pd.DataFrame()
for name,group in rain_df.groupby('station'):
    if df.empty:
        df = group.set_index("date")[["rain"]].rename(columns={'rain':name})
    else:
        df = df.join(group.set_index("date")[["rain"]].rename(columns={'rain':name}))

print(df.shape)
df.head()
# Out:
# (4961, 929)
#             ACRU  ANLI  BAKI  BARI  BBHN  BBON  BBUA  BBWN  BCAP  BCNG  ...  \
# date                                                                    ...
# 2007-01-01   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# 2007-01-02   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# 2007-01-03   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# 2007-01-04   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
# 2007-01-05   NaN   NaN   NaN   0.0   NaN   NaN   NaN   NaN   0.0   NaN  ...
#
#             YOM003  YOM004  YOM005  YOM006  YOM007  YOM008  YOM009  YOM010  \
# date
# 2007-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-02     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-03     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-04     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-05     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#             YOM011  YOM012
# date
# 2007-01-01     NaN     NaN
# 2007-01-02     NaN     NaN
# 2007-01-03     NaN     NaN
# 2007-01-04     NaN     NaN
# 2007-01-05     NaN     NaN
#
# [5 rows x 929 columns]

# %%
df['2012-01-01':] # eliminate most missing data
df.to_csv('instant_data/rain.csv')

# %% [markdown]
# # Water level

# %%
path_water = "hii-telemetering-batch-data-master/water-level2007-2020/"
water_df = open_concat_csv(path_water)

print(water_df.shape)
print(water_df.columns)
# Out:
# (225604800, 3)
# Index(['date_time', 'wl', 'station'], dtype='object')

# %%
water_df.rename(columns={'date_time':'date'},inplace=True)
water_df.head()
# Out:
#                  date  wl station
# 0 2007-01-01 00:00:00 NaN  TBW018
# 1 2007-01-01 00:10:00 NaN  TBW018
# 2 2007-01-01 00:20:00 NaN  TBW018
# 3 2007-01-01 00:30:00 NaN  TBW018
# 4 2007-01-01 00:40:00 NaN  TBW018

# %%
df = pd.DataFrame()
for name,group in water_df.groupby('station'):
    if df.empty:
        df = group.set_index("date")[["wl"]].rename(columns={'wl':name})
    else:
        df = df.join(group.set_index("date")[["wl"]].rename(columns={'wl':name}))

print(df.shape)
df.head()
# Out:
# (714384, 316)
#                      BKK001  BKK002  BKK003  BKK004  BKK005  BKK006  BKK007  \
# date
# 2007-01-01 00:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:10:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:20:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:30:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                      BKK008  BKK009  BKK012  ...  YOM003  YOM004  YOM005  \
# date                                         ...
# 2007-01-01 00:00:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2007-01-01 00:10:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2007-01-01 00:20:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2007-01-01 00:30:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2007-01-01 00:40:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
#
#                      YOM006  YOM007  YOM008  YOM009  YOM010  YOM011  YOM012
# date
# 2007-01-01 00:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:10:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:20:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:30:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [5 rows x 316 columns]

# %%
df['2012-01-01':] # eliminate most missing data
# Out:
#                      BKK001  BKK002  BKK003  BKK004  BKK005  BKK006  BKK007  \
# date
# 2012-01-01 00:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:10:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:20:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:30:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2020-07-31 23:10:00    0.43    0.34    1.28    0.62    0.31    0.92    0.98
# 2020-07-31 23:20:00    0.43    0.34    1.28    0.62    0.31    0.91    0.97
# 2020-07-31 23:30:00    0.43    0.34    1.28    0.63    0.31    0.90    0.98
# 2020-07-31 23:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2020-07-31 23:50:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                      BKK008  BKK009  BKK012  ...  YOM003  YOM004  YOM005  \
# date                                         ...
# 2012-01-01 00:00:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2012-01-01 00:10:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2012-01-01 00:20:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2012-01-01 00:30:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2012-01-01 00:40:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# ...                     ...     ...     ...  ...     ...     ...     ...
# 2020-07-31 23:10:00   -0.11   -0.09    -0.1  ...   154.7  137.61   60.44
# 2020-07-31 23:20:00   -0.12   -0.09    -0.1  ...   154.7  137.61   60.45
# 2020-07-31 23:30:00   -0.13   -0.09    -0.1  ...   154.7  137.61   60.45
# 2020-07-31 23:40:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
# 2020-07-31 23:50:00     NaN     NaN     NaN  ...     NaN     NaN     NaN
#
#                      YOM006  YOM007  YOM008  YOM009  YOM010  YOM011  YOM012
# date
# 2012-01-01 00:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:10:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:20:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:30:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2012-01-01 00:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2020-07-31 23:10:00   47.65   38.49   32.68   26.38  144.08  269.36   43.21
# 2020-07-31 23:20:00   47.65   38.49   32.68   26.39  144.09  269.36   43.21
# 2020-07-31 23:30:00   47.65   38.49   32.68   26.38  144.09  269.36   43.21
# 2020-07-31 23:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2020-07-31 23:50:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# [451440 rows x 316 columns]

# %%
df.to_csv('instant_data/water.csv')

# %% [markdown]
# # Small protype

# %%
path_rain = "hii-telemetering-batch-data-master/small/rain/"
rain_df_small = open_concat_csv(path_rain)
path_water = "hii-telemetering-batch-data-master/small/water/"
water_df_small = open_concat_csv(path_water)

# %%
water_df_small.rename(columns={'date_time':'date'},inplace=True)
df = pd.DataFrame()
for name,group in water_df_small.groupby('station'):
    if df.empty:
        df = group.set_index("date")[["wl"]].rename(columns={'wl':name})
    else:
        df = df.join(group.set_index("date")[["wl"]].rename(columns={'wl':name}))

print(df.shape)
df.head()
# Out:
# (714384, 17)
#                      CHM002  CHM004  CHM006  CPY003  CPY004  CPY009  CPY010  \
# date
# 2007-01-01 00:00:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:10:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:20:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:30:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                      CPY015  KWN002  NAN009  NAN010  NAN011  NAN012  NAN013  \
# date
# 2007-01-01 00:00:00     NaN     NaN     NaN     NaN   55.09     NaN     NaN
# 2007-01-01 00:10:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:20:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:30:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-01 00:40:00     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#                      PIN001  PIN004  THA001
# date
# 2007-01-01 00:00:00     NaN     NaN     NaN
# 2007-01-01 00:10:00     NaN     NaN     NaN
# 2007-01-01 00:20:00     NaN     NaN     NaN
# 2007-01-01 00:30:00     NaN     NaN     NaN
# 2007-01-01 00:40:00     NaN     NaN     NaN

# %%
df['2013-01-01':].to_csv('instant_data/water_small.csv')

# %%
df = pd.DataFrame()
for name,group in rain_df_small.groupby('station'):
    if df.empty:
        df = group.set_index("date")[["rain"]].rename(columns={'rain':name})
    else:
        df = df.join(group.set_index("date")[["rain"]].rename(columns={'rain':name}))

print(df.shape)
df.head()
# Out:
# (4961, 18)
#             CHM002  CHM004  CHM006  CPY004  CPY009  CPY010  CPY015  KWN002  \
# date
# 2007-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-02     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-03     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-04     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-05     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#             NAN006  NAN010  NAN011  NAN012  NAN013  PIN001  PIN003  PIN004  \
# date
# 2007-01-01     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-02     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-03     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-04     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2007-01-05     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#             PIN005  THA001
# date
# 2007-01-01     NaN     NaN
# 2007-01-02     NaN     NaN
# 2007-01-03     NaN     NaN
# 2007-01-04     NaN     NaN
# 2007-01-05     NaN     NaN

# %%
df['2013-01-01':].to_csv('instant_data/rain_small.csv')
