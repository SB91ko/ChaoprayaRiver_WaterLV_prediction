# %%
from DLtools.Data_preprocess import series_to_supervised,load_data,preprocess

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
r='data/instant_data/rain_small.csv'
w='data/instant_data/water_small.csv'
rw = load_data(r,w)
df =rw.df.resample('d').mean()
# Out:
# DataFrame shape: (465169, 35)

# %% [markdown]
# # Preprocessing

# %%
X_in = df['CPY015_w']["2015-01-01":"2018-01-05"].interpolate(limit=7)
X_in = X_in.astype('float32')

# %%
scaler_target = MinMaxScaler()
X_in = scaler_target.fit_transform(X_in.values.reshape(-1,1))
print(np.min(X_in),np.max(X_in))
# Out:
# 0.0 0.99999994

# %%
LOOKBACK=7

prep = preprocess(X_in,Y_column=None,n_timelag=LOOKBACK,n_feature=1,scale_ornot=False)
train_X, train_Y = prep.train_X,prep.train_Y
val_X,val_y = prep.val_X,prep.val_y
test_X,test_y =prep.test_X,prep.test_Y

X,Y = prep.train_val_X,prep.train_val_Y

#ori_trainX,ori_trianY = prep.ori_trainX,prep.ori_trainY
# Out:
# ================================================== preview Supervised ==================================================
#     var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 7    0.472028   0.482842   0.452263   0.426650   0.472951   0.450788
# 8    0.482842   0.452263   0.426650   0.472951   0.450788   0.458488
# 9    0.452263   0.426650   0.472951   0.450788   0.458488   0.497855
# 10   0.426650   0.472951   0.450788   0.458488   0.497855   0.555700
# 11   0.472951   0.450788   0.458488   0.497855   0.555700   0.439965
#
#     var1(t-1)   var1(t)
# 7    0.458488  0.497855
# 8    0.497855  0.555700
# 9    0.555700  0.439965
# 10   0.439965  0.352934
# 11   0.352934  0.391659
#       var1(t-7)  var1(t-6)  var1(t-5)  var1(t-4)  var1(t-3)  var1(t-2)  \
# 1096   0.156412   0.354789   0.396031   0.459752   0.429060   0.483637
# 1097   0.354789   0.396031   0.459752   0.429060   0.483637   0.652490
# 1098   0.396031   0.459752   0.429060   0.483637   0.652490   0.630456
# 1099   0.459752   0.429060   0.483637   0.652490   0.630456   0.629742
# 1100   0.429060   0.483637   0.652490   0.630456   0.629742   0.637389
#
#       var1(t-1)   var1(t)
# 1096   0.652490  0.630456
# 1097   0.630456  0.629742
# 1098   0.629742  0.637389
# 1099   0.637389  0.514469
# 1100   0.514469  0.383327
# (1094, 8)
# 1094
# ================================================== X-Y Shape ==================================================
# (1094, 7) ||******call ____ ori_x******
# (1094,) ||******call ____ ori_y******
# ================================================== Train....Validation...Test ==================================================
# Train:Test (765, 7) (765, 1) (329, 7) (329, 1)
# Train.... (535, 7) (535, 1) ||
# Val...... (230, 7) (230, 1) ||
# ================================================== [Reshape Train for 3D]Train....Validation...Test ==================================================
# Train:Test (765, 7, 1) (765, 1) (329, 7) (329, 1) || ori_trainX,ori_trainY....test_X,test_Y
# Train.... (535, 7, 1) (535, 1) || train_X, train_Y
# Val...... (230, 7, 1) (230, 1) || val_X, val_Y

# %% [markdown]
# # LSTM

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.callbacks import EarlyStopping

# %%
EPOCH = 100
BATCH = 7
VALIDATION = (val_X,val_y)

callback_early_stopping = EarlyStopping(monitor='val_loss',patience=5, verbose=2)
callbacks = [callback_early_stopping]

# %%
model = Sequential()
model.add(LSTM(128, activation='relu', input_shape=(LOOKBACK, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               66560
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_Y, epochs=EPOCH, batch_size=BATCH, verbose=1,shuffle=False,validation_data=VALIDATION,callbacks=callbacks)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 16ms/step - loss: 0.0378 - val_loss: 0.0087
# Epoch 2/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0068 - val_loss: 0.0079
# Epoch 3/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0064 - val_loss: 0.0077
# Epoch 4/100
# 77/77 [==============================] - 1s 16ms/step - loss: 0.0063 - val_loss: 0.0075
# Epoch 5/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 6/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0060 - val_loss: 0.0073
# Epoch 7/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0059 - val_loss: 0.0072
# Epoch 8/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0058 - val_loss: 0.0071
# Epoch 9/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 10/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0056 - val_loss: 0.0069
# Epoch 11/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0055 - val_loss: 0.0069
# Epoch 12/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0054 - val_loss: 0.0068
# Epoch 13/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 14/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0053 - val_loss: 0.0067
# Epoch 15/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0052 - val_loss: 0.0066
# Epoch 16/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 17/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 18/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 19/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0051 - val_loss: 0.0065
# Epoch 20/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 21/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 22/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 23/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 24/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0049 - val_loss: 0.0062
# Epoch 25/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0062
# Epoch 26/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0049 - val_loss: 0.0061
# Epoch 27/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0048 - val_loss: 0.0061
# Epoch 28/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0061
# Epoch 29/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 30/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 31/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 32/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 33/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 34/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 35/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0048 - val_loss: 0.0059
# Epoch 36/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 37/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 38/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 39/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 40/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0058
# Epoch 41/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 42/100
# 77/77 [==============================] - 1s 10ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 43/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 44/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 45/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 46/100
# 77/77 [==============================] - 1s 16ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 47/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 48/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 49/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 50/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 51/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 52/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 53/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 54/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 55/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 56/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 57/100
# 77/77 [==============================] - 2s 21ms/step - loss: 0.0047 - val_loss: 0.0057
# Epoch 58/100
# 77/77 [==============================] - 1s 11ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 59/100
# 77/77 [==============================] - 1s 12ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 60/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 61/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 62/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 63/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 64/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 65/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 66/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 67/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 68/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 69/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 70/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 71/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.0046 - val_loss: 0.0056
# Epoch 72/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 73/100
# 77/77 [==============================] - 2s 21ms/step - loss: 0.0046 - val_loss: 0.0057
# Epoch 00073: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# generate predictions for training
trainPredict = model.predict(X)
testPredict = model.predict(test_X)

# %%
#plot the result from model prediction

result_test = np.squeeze(trainPredict)
true_data = np.squeeze(Y)

plt.figure(figsize=(20,5))
plt.plot(true_data, label='True')
plt.plot(result_test, label='LSTM')
plt.title("LSTM's_Prediction")
plt.xlabel('Observation')
plt.ylabel('Water lv')

plt.legend()
plt.show()

# %%
# Estimate model performance
trainScore = model.evaluate(X,Y, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(test_X,test_y, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.00 MSE (0.07 RMSE)
# Test Score: 0.01 MSE (0.11 RMSE)

# %%
import hydroeval

trainScore = hydroeval.nse(trainPredict,Y)
print('Train Score: %.2f NSE ' % (trainScore))
testScore = hydroeval.nse(testPredict,test_y)
print('Test Score: %.2f NSE ' % (testScore))
# Out:
# Train Score: 0.69 NSE
# Test Score: 0.56 NSE

# %%
scale_trainPredict = scaler_target.inverse_transform(trainPredict)
scale_testPredict = scaler_target.inverse_transform(testPredict)
scale_X_in = scaler_target.inverse_transform(X_in)

print(np.min(scale_X_in),np.max(scale_X_in))
print(np.min(scale_trainPredict),np.max(scale_trainPredict))
print(np.min(scale_testPredict),np.max(scale_testPredict))
# Out:
# -0.26214287 1.3105556
# 0.040029313 1.0049129
# 0.23410739 1.2057053

# %%
# # # shift train predictions for plotting
# trainPredictPlot = np.empty_like(X_in)
# trainPredictPlot[:] = np.nan
# trainPredictPlot = trainPredictPlot.reshape(-1,1)
# trainPredictPlot[LOOKBACK:len(trainPredict)+LOOKBACK,:] = trainPredict
# # # shift test predictions for plotting
# # testPredictPlot = np.empty_like(X_in)
# # testPredictPlot[:] = np.nan
# # testPredictPlot = testPredictPlot.reshape(-1,1)
# # testPredictPlot[len(trainPredict)+(LOOKBACK*2)+1:len(X_in)-1, :] = testPredict
# # plot baseline and predictions
# plt.figure(figsize=(20,5))
# plt.plot(X_in[LOOKBACK:-LOOKBACK])
# plt.plot(trainPredictPlot)
# #plt.plot(testPredictPlot)
# plt.show()
