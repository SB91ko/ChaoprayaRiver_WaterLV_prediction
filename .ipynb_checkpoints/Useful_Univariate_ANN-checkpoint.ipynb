# %%
from DLtools.Data_preprocess import series_to_supervised,load_data,manual_trian_test_split

import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
r='data/instant_data/rain_small.csv'
w='data/instant_data/water_small.csv'
rw = load_data(r,w)
df =rw.df.resample('d').mean()
df_w = rw.water_df
df_r = rw.rain_df
# Out:
# DataFrame shape: (465169, 35)

# %%
fig,ax =plt.subplots(2,1,figsize=(20,5))
ax[0].plot(df['CPY015_w']['2013-01-01':'2015-01-01'])
ax[1].plot(df_w['CPY015_w']['2013-01-01':'2015-01-01'])

# %% [markdown]
# # Preprocessing

# %%
X = df['CPY015_w']["2015-01-01":"2018-01-05"].interpolate(limit=7).values
X = X.astype('float32')

# %%
LOOKBACK = 7
Xtrain,Ytrain,Xtest,Ytest = manual_trian_test_split(X,LOOKBACK)
print(Xtrain.shape,Ytrain.shape)
print(Xtest.shape,Ytest.shape)
# Out:
# Shape of train:... (762, 7) (762,)
# Shape of test:... (323, 7) (323,)
# (762, 7) (762,)
# (323, 7) (323,)

# %% [markdown]
# # MPL multi perceptron layer

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
EPOCH = 100
BATCH = 2
VALIDATION = (Xtest,Ytest)

# %%
model = Sequential()
model.add(Dense(8, input_dim=LOOKBACK, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 8)                 64
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 73
# Trainable params: 73
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(Xtrain, Ytrain, epochs=EPOCH, batch_size=BATCH, verbose=1,shuffle=False,validation_data=VALIDATION)
# Out:
# Epoch 1/100
# 381/381 [==============================] - 3s 7ms/step - loss: 0.0317 - val_loss: 0.0403
# Epoch 2/100
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0252 - val_loss: 0.0349
# Epoch 3/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0219 - val_loss: 0.0313
# Epoch 4/100
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0197 - val_loss: 0.0289
# Epoch 5/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0180 - val_loss: 0.0272
# Epoch 6/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0167 - val_loss: 0.0259
# Epoch 7/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0156 - val_loss: 0.0250
# Epoch 8/100
# 381/381 [==============================] - 2s 4ms/step - loss: 0.0147 - val_loss: 0.0245
# Epoch 9/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0141 - val_loss: 0.0242
# Epoch 10/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0136 - val_loss: 0.0243
# Epoch 11/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0134 - val_loss: 0.0243
# Epoch 12/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0132 - val_loss: 0.0243
# Epoch 13/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0130 - val_loss: 0.0244
# Epoch 14/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0129 - val_loss: 0.0245
# Epoch 15/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0128 - val_loss: 0.0245
# Epoch 16/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0127 - val_loss: 0.0246
# Epoch 17/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0126 - val_loss: 0.0247
# Epoch 18/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0126 - val_loss: 0.0247
# Epoch 19/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0125 - val_loss: 0.0248
# Epoch 20/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0125 - val_loss: 0.0248
# Epoch 21/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0125 - val_loss: 0.0249
# Epoch 22/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0124 - val_loss: 0.0249
# Epoch 23/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0124 - val_loss: 0.0249
# Epoch 24/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0124 - val_loss: 0.0249
# Epoch 25/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0250
# Epoch 26/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0250
# Epoch 27/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0250
# Epoch 28/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0250
# Epoch 29/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0250
# Epoch 30/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0123 - val_loss: 0.0250
# Epoch 31/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0251
# Epoch 32/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0251
# Epoch 33/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0251
# Epoch 34/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0251
# Epoch 35/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0252
# Epoch 36/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0122 - val_loss: 0.0252
# Epoch 37/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0252
# Epoch 38/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0122 - val_loss: 0.0252
# Epoch 39/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0253
# Epoch 40/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0121 - val_loss: 0.0253
# Epoch 41/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0254
# Epoch 42/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0256
# Epoch 43/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0121 - val_loss: 0.0255
# Epoch 44/100
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0121 - val_loss: 0.0257
# Epoch 45/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0121 - val_loss: 0.0256
# Epoch 46/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0121 - val_loss: 0.0257
# Epoch 47/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0121 - val_loss: 0.0260
# Epoch 48/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0121 - val_loss: 0.0260
# Epoch 49/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0120 - val_loss: 0.0262
# Epoch 50/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0262
# Epoch 51/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0259
# Epoch 52/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0258
# Epoch 53/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0264
# Epoch 54/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0265
# Epoch 55/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0266
# Epoch 56/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0261
# Epoch 57/100
# 381/381 [==============================] - 1s 1ms/step - loss: 0.0120 - val_loss: 0.0259
# Epoch 58/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0120 - val_loss: 0.0264
# Epoch 59/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0265
# Epoch 60/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0261
# Epoch 61/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0268
# Epoch 62/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0268
# Epoch 63/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0263
# Epoch 64/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0270
# Epoch 65/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0271
# Epoch 66/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0265
# Epoch 67/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0273
# Epoch 68/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0119 - val_loss: 0.0267
# Epoch 69/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0119 - val_loss: 0.0268
# Epoch 70/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0269
# Epoch 71/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0279
# Epoch 72/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0279
# Epoch 73/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0281
# Epoch 74/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0282
# Epoch 75/100
# 381/381 [==============================] - 2s 5ms/step - loss: 0.0118 - val_loss: 0.0275
# Epoch 76/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0285
# Epoch 77/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0276
# Epoch 78/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0284
# Epoch 79/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0291
# Epoch 80/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0118 - val_loss: 0.0287
# Epoch 81/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0287
# Epoch 82/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0118 - val_loss: 0.0288
# Epoch 83/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0292
# Epoch 84/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0118 - val_loss: 0.0289
# Epoch 85/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0293
# Epoch 86/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0291
# Epoch 87/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0291
# Epoch 88/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0294
# Epoch 89/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0292
# Epoch 90/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0296
# Epoch 91/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0117 - val_loss: 0.0293
# Epoch 92/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0292
# Epoch 93/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0297
# Epoch 94/100
# 381/381 [==============================] - 1s 4ms/step - loss: 0.0117 - val_loss: 0.0294
# Epoch 95/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0298
# Epoch 96/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0292
# Epoch 97/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0291
# Epoch 98/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0116 - val_loss: 0.0295
# Epoch 99/100
# 381/381 [==============================] - 1s 2ms/step - loss: 0.0117 - val_loss: 0.0292
# Epoch 100/100
# 381/381 [==============================] - 1s 3ms/step - loss: 0.0117 - val_loss: 0.0291

# %% [markdown]
# # Evaluate Result

# %%
# Estimate model performance
trainScore = model.evaluate(Xtrain, Ytrain, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (trainScore, math.sqrt(trainScore)))
testScore = model.evaluate(Xtest, Ytest, verbose=0)
print('Test Score: %.2f MSE (%.2f RMSE)' % (testScore, math.sqrt(testScore)))
# Out:
# Train Score: 0.01 MSE (0.11 RMSE)
# Test Score: 0.03 MSE (0.17 RMSE)

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# generate predictions for training
trainPredict = model.predict(Xtrain)
testPredict = model.predict(Xtest)

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(X.reshape(-1,1))
trainPredictPlot[:] = np.nan
trainPredictPlot[LOOKBACK:len(trainPredict)+LOOKBACK, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = np.empty_like(X.reshape(-1,1))
testPredictPlot[:] = np.nan
testPredictPlot[len(trainPredict)+(LOOKBACK*2)+1:len(X)-1, :] = testPredict
# plot baseline and predictions
plt.figure(figsize=(20,5))
plt.plot(X)
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
